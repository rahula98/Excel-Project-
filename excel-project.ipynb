# %% [markdown]
# # Excel Project
#
# **Why is data cleaning important**
# * Removes errors and duplicates
# * Makes data more consistent - meaning higher reliability
# * Leads to better business decisions
#
# Dataset used in this project can be found [here](https://github.com/AlexTheAnalyst/Excel-Tutorial/blob/main/Excel%20Project%20Dataset.xlsx)
#
# # Data cleaning
#
# Step 1 - Load the .csv file and create three tabs; working sheet, pivot tables and dashboard.
#
# ![image.png](attachment:f6b9674f-e919-4744-b660-3bdf814c50ff.png)
#
# Step 2 - Copy the bike_buyers_orginal to the working sheet.
#
# Step 3 - Check for duplicates. This is done by going to the Data tab --> Remove Duplicates --> Select All then press OK.
#
# ![image.png](attachment:5d20b42e-7323-4da0-b94c-1e689ade0f5c.png)
#
#
# ![image.png](attachment:73f3852a-00ce-4a88-b49d-06c3136b7638.png)

# %% [markdown]
# Step 4 - Changing the Matial Status and Gender Names
# Martial Status - M --> Married , S -> Single
# Gender Names - M --> Male, F --> Female
#
# ![image.png](attachment:7e645370-ce61-41fc-922d-70a3b976b006.png)
#
# Step 5 - Remove .00 from Income column
#
# Step 6 -  Age column ranges from 23-89 therefore we will create ranges. Created a new column called Age ranges. Then used a IF statement.
#
# =IF(L13>54, "Old", IF(L13 >= 31, "Middle Age",IF(L23<31, "Adolescent", "Invaild")))
#
# ![image.png](attachment:e219d5ea-5191-40a1-a24f-214b08c75e64.png)

# %% [markdown]
# # Creating Pivot Tables
#
# Step 1 - Go to the Pivot tables tab and Create a new Pivot Table. Then select ID cell in Working Sheet followed by Ctrl + A.
#
# ![image.png](attachment:af87b65b-cc1d-4683-8f45-c4a4d748575b.png)
#
# Step 2 - Added the relevant columns as seen in the screenshot below.
#
# ![image.png](attachment:b05d2cb8-54ed-4f37-a0b2-18fb63a27d07.png)
#
# Step 3 - Changed the labels and added a title.
#
# ![image.png](attachment:df579afd-dfb6-41eb-9d25-a331430c3b9e.png)
#
# Step 4 - Removed the decimal places for the purpose of readability.
#
# ![image.png](attachment:0ad18c22-b580-4d1c-a7e0-57e918ba2806.png)
#
# Step 5 - Repeated Step 1 but with different attributes.
#
# ![image.png](attachment:d43a2327-79c3-451a-87de-58d7e11f0915.png)
#
# Step 6 - Repeat Step 1 and create the last pivot table. See screenshot for attributes and naming of graph.
#
# ![image.png](attachment:4e62686d-87a3-4869-bc03-f80664af6b0a.png)

# %% [markdown]
# # Dashboard
#
# Step 1 - Created a dashboard as seen in the screenshot below.
#
# ![image.png](attachment:ffc31119-eb93-44e9-bfb8-c1c2c872faf2.png)
#
# Step 2 - Added a slicer so we can change between the Married and Single status for all graphs. This was completed by Clicking the Slicer and choose Report Connections
#
# ![image.png](attachment:9f4a8d3a-ed99-4f60-a764-d4d146fa4269.png)
#
# # Review of Final Dashboard
#
# We can filter to see different demographic and how they filter from each other.
#
# ![image.png](attachment:58f2f45c-c6ed-4252-b472-8ba7079a4515.png)
